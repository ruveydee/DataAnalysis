# %%
#import necessary libraries
import pandas as pd 
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("./Sales_Data/Sales_April_2019.csv")
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
files = [file for file in os.listdir("./Sales_Data")]
files
# Out:
# ['Sales_December_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv']

# %%
#merge data fram each month into one csv
df_all=pd.DataFrame()

for file in files:
    df1 = pd.read_csv("./Sales_Data/" + file)
    df_all= pd.concat([df_all, df1])

# %%
df_all.to_csv("total.csv", index=False)

# %%
df= pd.read_csv("total.csv")

# %%
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df.dropna(axis=0,how="all",inplace=True)

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# ## 1-What was the best month for sales? How much was earned that month?

# %%
df["month"]=df["Order Date"].str[0:2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   month             186305 non-null  object
# dtypes: object(7)
# memory usage: 11.4+ MB

# %%
df1=df[df["month"]!="Or"]

# %%
df1.month=df1.month.astype("int32")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  int32
# dtypes: int32(1), object(6)
# memory usage: 10.6+ MB

# %%
df1["Price Each"]=pd.to_numeric(df1["Price Each"])

# %%
df1["Price Each"].dtype
# Out:
# dtype('float64')

# %%
df1["Quantity Ordered"]=pd.to_numeric(df1["Quantity Ordered"])

# %%
df1["Sales"]=df1["Quantity Ordered"]*df1["Price Each"]
df1
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month    Sales
# ...

# %%
result=df1.groupby("month").sum()
result.reset_index(inplace=True)

# %%
result
# Out:
#     month  Quantity Ordered  Price Each       Sales
# 0       1             10903  1811768.38  1822256.73
# 1       2             13449  2188884.72  2202022.42
# 2       3             17005  2791207.83  2807100.38
# 3       4             20558  3367671.02  3390670.24
# 4       5             18667  3135125.13  3152606.75
# 5       6             15253  2562025.61  2577802.26
# 6       7             16072  2632539.56  2647775.76
# 7       8             13448  2230345.42  2244467.88
# 8       9             13109  2084992.09  2097560.13
# 9      10             22703  3715554.83  3736726.88
# 10     11             19798  3180600.68  3199603.20
# 11     12             28114  4588415.41  4613443.34

# %%
plt.figure(figsize=(8,6))
plt.bar(data=result, x="month", height="Sales")
plt.xticks(result.month)
plt.xlabel("Months")
plt.ylabel("Sales in USD ($)");

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=result, x="month", y="Sales");

# %% [markdown]
# # 2-What is city had the highest number of sales?

# %%
df1
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month    Sales
# ...

# %%
df1["city"]=df1["Purchase Address"].apply(lambda x:x.split(",")[1])

# %%
df1
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month  \
# ...

# %%
def get_city(adress):
    return adress.split(",")[1]
    
def get_state(adress):
    return adress.split(",")[2].split(" ")[1]

df1["city"]=df1["Purchase Address"].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
df1.sample(5)
# Out:
#        Order ID                Product  Quantity Ordered  Price Each  \
# 181020   217348  AA Batteries (4-pack)                 1        3.84
# 123562   265557       Wired Headphones                 1       11.99
# 41488    192177       Wired Headphones                 1       11.99
# 43409    194008       Wired Headphones                 1       11.99
# 4379     299828       Wired Headphones                 1       11.99
#
#             Order Date                         Purchase Address  month  Sales  \
# 181020  06/20/19 23:22  690 Hickory St, San Francisco, CA 94016      6   3.84
# 123562  10/25/19 20:16            441 4th St, Seattle, WA 98101     10  11.99
# 41488   04/27/19 19:40    130 Hickory St, Los Angeles, CA 90001      4  11.99
# 43409   04/12/19 18:09      425 Elm St, San Francisco, CA 94016      4  11.99
# 4379    12/30/19 06:43        527 Dogwood St, Atlanta, GA 30301     12  11.99
#
#                        city
# 181020   San Francisco (CA)
# ...

# %%
df1.groupby("city").Sales.sum().nlargest(1)
# Out:
# city
#  San Francisco (CA)    8262203.91
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=df1, x=df1.groupby("city").Sales.sum().index, y=df1.groupby("city").Sales.sum().values)
plt.xticks(rotation=90)
plt.xlabel("City Name")
plt.ylabel("Sales in USD$");

# %% [markdown]
# Let's see which city has the highest sales! San Francisco

# %% [markdown]
# # 3-What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
df1["Order Date"]=pd.to_datetime(df1["Order Date"])

# %%
df1.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
#                   city
# 0   New York City (NY)
# 1   New York City (NY)
# 2   New York City (NY)
# ...

# %%
df1["hour"]=df1["Order Date"].dt.hour #we have created hour column and minute column 
df1["minute"]=df1["Order Date"].dt.minute 
df1.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
#                   city  hour  minute
# 0   New York City (NY)     0       1
# 1   New York City (NY)     7       3
# ...

# %%
df4=df1.groupby("hour")["Order ID"].count()
df4
# Out:
# hour
# 0      3910
# 1      2350
# 2      1243
# 3       831
# 4       854
# 5      1321
# 6      2482
# 7      4011
# 8      6256
# 9      8748
# 10    10944
# 11    12411
# 12    12587
# 13    12129
# 14    10984
# 15    10175
# 16    10384
# 17    10899
# 18    12280
# 19    12905
# 20    12228
# 21    10921
# 22     8822
# 23     6275
# Name: Order ID, dtype: int64

# %%
plt.figure(figsize=(8,6))
df4.plot()
plt.grid()
plt.xticks(df4.index);

# %% [markdown]
#  My recommendation is slightly before 12am or 7pm

# %% [markdown]
# # 4-How product are most often sold together?

# %%
df1.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
#                   city  hour  minute
# 0   New York City (NY)     0       1
# 1   New York City (NY)     7       3
# ...

# %%
dff=df1[df1["Order ID"].duplicated(keep=False)]

dff["grouped"]=df1.groupby("Order ID")["Product"].transform(lambda x:','.join(x))

# %%
dff=dff[["Order ID", "grouped"]].drop_duplicates()
dff
# Out:
#        Order ID                                            grouped
# 16       295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36       295698               Vareebadd Phone,USB-C Charging Cable
# 42       295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66       295726                    iPhone,Lightning Charging Cable
# 76       295735   iPhone,Apple Airpods Headphones,Wired Headphones
# ...         ...                                                ...
# 186798   222863        27in FHD Monitor,Bose SoundSport Headphones
# 186804   222868                    iPhone,Apple Airpods Headphones
# 186819   222882     Apple Airpods Headphones,AA Batteries (4-pack)
# 186822   222884                  Google Phone,USB-C Charging Cable
# 186842   222903                    iPhone,Lightning Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in dff['grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# # 5-What product sold the most? Why do you think it sold the most?

# %%
product_group = df1.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
prices = df1.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(keys, rotation='vertical', size=8)

fig.show()

# %% [markdown]
# ...
